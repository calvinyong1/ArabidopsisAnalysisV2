# %%
import os
import shutil
import nibabel as nib
import cv2
import numpy as np
import pathlib
import re
import json
from collections import defaultdict
import random

def natural_sort_key(s, _nsre=re.compile('([0-9]+)')):
    return [int(text) if text.isdigit() else text.lower()
            for text in re.split(_nsre, s)]

# Input directories
path = "/Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset"
read_path = pathlib.Path(path).glob('*/*/*/*.png')
image_paths = sorted([str(path) for path in read_path], key=natural_sort_key)

# Output directories
outpath = "/Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/nnUNet_temp_rebuild/Dataset789_ChronoRoot2/imagesTr"
labels_outpath = "/Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/nnUNet_temp_rebuild/Dataset789_ChronoRoot2/labelsTr"

os.makedirs(outpath, exist_ok=True)
os.makedirs(labels_outpath, exist_ok=True)

# Group images by folder
folder_images = defaultdict(list)
for path in image_paths:
    # Get the folder path - using os.path for better compatibility
    folder_path = os.path.dirname(path)
    folder_images[folder_path].append(path)

# Create a mapping dictionary that includes the folder info
folder_image_map = defaultdict(list)

# Counter for image naming
counter = 1
image_id = ""

# Process all images grouped by folder
for folder, images in folder_images.items():
    folder_id = "Manual_Annotation_" + folder.replace("/", "_").replace(" ", "_")  # Create a safe folder ID
    
    print(f'Processing {folder}, image ID: {image_id}')
        
    # Process each image in the folder
    for path in images:
        # Create image ID
        image_id = f'image_{counter}'
        
        # Copy the image to the output directory
        shutil.copy(path, os.path.join(outpath, f'{image_id}_0000.png'))
        
        # Load the mask
        mask_path = path.replace('.png', '.nii.gz')
        mask = nib.load(mask_path).get_fdata().T
        
        if mask.shape[0] == 1:
            mask = mask[0]
        
        image = cv2.imread(path, 0)
        # Image shape and mask shape should be the same
        if image.shape[0] != mask.shape[0]:
            continue

        # Save the mask
        cv2.imwrite(os.path.join(labels_outpath, f'{image_id}.png'), mask.astype('uint8'))
        
        folder_image_map[folder_id].append(image_id)
        
        # Update the counter
        counter += 1

with open('/Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/nnUNet_temp_rebuild/Dataset789_ChronoRoot2/folder_image_map.json', '+w') as f:
    json.dump(folder_image_map, f, indent=4)
# Out:
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Etiolation/MultipleVids/Primeras, image ID:
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Etiolation/MultipleVids/Varios, image ID: image_4
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Etiolation/rpi101_2024-07-29_14-47/1, image ID: image_12
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Etiolation/rpi101_2024-07-29_14-47/2, image ID: image_16
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Etiolation/rpi101_2024-07-29_14-47/3, image ID: image_20
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Etiolation/rpi101_2024-11-06_15-18/1, image ID: image_24
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Etiolation/rpi101_2024-11-06_15-18/2, image ID: image_29
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Etiolation/rpi101_2024-11-06_15-18/3, image ID: image_34
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Etiolation/rpi101_2024-11-06_15-18/4, image ID: image_39
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Etiolation/rpi102_2024-06-11_14-10/1, image ID: image_44
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Etiolation/rpi102_2024-06-11_14-10/2, image ID: image_48
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Etiolation/rpi102_2024-06-11_14-10/3, image ID: image_52
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Etiolation/rpi102_2024-06-11_14-10/4, image ID: image_56
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Etiolation/rpi102_2024-07-29_14-54/1, image ID: image_60
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Etiolation/rpi102_2024-07-29_14-54/2, image ID: image_64
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Etiolation/rpi102_2024-07-29_14-54/3, image ID: image_68
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Etiolation/rpi102_2024-07-29_14-54/4, image ID: image_72
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Etiolation/rpi103_2024-11-06_15-23/1, image ID: image_76
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Etiolation/rpi103_2024-11-06_15-23/2, image ID: image_81
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Etiolation/rpi103_2024-11-06_15-23/3, image ID: image_86
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Etiolation/rpi103_2024-11-06_15-23/4, image ID: image_91
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Etiolation/rpi103_2025-06-27_15-00/1, image ID: image_96
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Etiolation/rpi103_2025-06-27_15-00/2, image ID: image_100
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Etiolation/rpi103_2025-06-27_15-00/3, image ID: image_104
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Etiolation/rpi103_2025-07-02_14-36/1, image ID: image_108
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Etiolation/rpi103_2025-07-02_14-36/2, image ID: image_112
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Etiolation/rpi103_2025-07-02_14-36/3, image ID: image_116
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Etiolation/rpi103_2025-07-02_14-36/4, image ID: image_120
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Germination/MultipleVids/AnnotatedSeeds, image ID: image_124
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Germination/MultipleVids/Varios, image ID: image_188
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Germination/rpi8_2024-07-02_14-41/1, image ID: image_210
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Germination/rpi12_2024-07-02_14-40/1, image ID: image_212
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Germination/rpi12_2024-07-02_14-40/2, image ID: image_214
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Germination/rpi12_2024-07-02_14-40/3, image ID: image_216
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Germination/rpi12_2024-07-02_14-40/4, image ID: image_218
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Germination/rpi12_2024-07-08_15-50/1, image ID: image_220
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Germination/rpi12_2024-07-08_15-50/2, image ID: image_222
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Germination/rpi12_2024-07-08_15-50/3, image ID: image_224
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Germination/rpi12_2024-07-08_15-50/4, image ID: image_226
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Germination/rpi12_2024-07-16_10-09/1, image ID: image_228
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Germination/rpi12_2024-07-16_10-09/2, image ID: image_230
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Germination/rpi12_2024-07-16_10-09/3, image ID: image_231
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Germination/rpi12_2024-07-16_10-09/4, image ID: image_232
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Germination/rpi12_2024-07-22_13-29/1, image ID: image_233
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Germination/rpi12_2024-07-22_13-29/2, image ID: image_234
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Germination/rpi12_2024-07-22_13-29/3, image ID: image_235
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Germination/rpi12_2024-07-22_13-29/4, image ID: image_236
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Germination/rpi20_2024-07-16_10-10/1, image ID: image_237
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Germination/rpi20_2024-07-16_10-10/2, image ID: image_238
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Germination/rpi20_2024-07-16_10-10/3, image ID: image_240
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Germination/rpi20_2024-07-16_10-10/4, image ID: image_241
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Germination/rpi20_2024-07-22_13-31/1, image ID: image_242
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Germination/rpi20_2024-07-22_13-31/2, image ID: image_244
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Germination/rpi20_2024-07-22_13-31/3, image ID: image_246
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Germination/rpi20_2024-07-22_13-31/4, image ID: image_249
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Germination/rpi101_2024-09-06_16-14/1, image ID: image_251
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Germination/rpi101_2024-09-06_16-14/2, image ID: image_256
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Germination/rpi101_2024-09-06_16-14/3, image ID: image_261
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Germination/rpi101_2024-09-06_16-14/4, image ID: image_266
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Germination/rpi101_2025-04-25_14-50/1, image ID: image_271
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Germination/rpi101_2025-04-25_14-50/2, image ID: image_275
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Germination/rpi101_2025-04-25_14-50/3, image ID: image_279
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Germination/rpi101_2025-04-25_14-50/4, image ID: image_283
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/ManyRoots/rpi101_2024-11-25_14-48/1, image ID: image_287
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/ManyRoots/rpi101_2024-11-25_14-48/2, image ID: image_294
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/ManyRoots/rpi101_2024-11-25_14-48/3, image ID: image_301
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/ManyRoots/rpi101_2024-11-25_14-48/4, image ID: image_308
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/ManyRoots/rpi101_2025-04-16_17-10/1, image ID: image_315
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/ManyRoots/rpi101_2025-04-16_17-10/2, image ID: image_321
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/ManyRoots/rpi101_2025-04-16_17-10/3, image ID: image_327
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/ManyRoots/rpi101_2025-04-16_17-10/4, image ID: image_333
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/ManyRoots/rpi103_2024-11-25_14-49/1, image ID: image_339
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/ManyRoots/rpi103_2024-11-25_14-49/2, image ID: image_346
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/ManyRoots/rpi103_2024-11-25_14-49/3, image ID: image_353
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/ManyRoots/rpi103_2024-11-25_14-49/4, image ID: image_360
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/ManyRoots/rpi103_2025-04-16_17-11/1, image ID: image_367
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/ManyRoots/rpi103_2025-04-16_17-11/2, image ID: image_373
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/ManyRoots/rpi103_2025-04-16_17-11/3, image ID: image_379
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/ManyRoots/rpi103_2025-04-16_17-11/4, image ID: image_385
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/MultipleVids/rotas, image ID: image_391
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/rpi4_old/cam2, image ID: image_404
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/rpi5_old/cam1, image ID: image_412
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/rpi6/1, image ID: image_419
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/rpi6/2, image ID: image_423
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/rpi6/3, image ID: image_428
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/rpi6/4, image ID: image_433
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/rpi6_2019-12-09_16-12/1, image ID: image_438
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/rpi6_2019-12-09_16-12/2, image ID: image_443
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/rpi6_2019-12-09_16-12/3, image ID: image_448
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/rpi6_2019-12-09_16-12/4, image ID: image_453
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/rpi6_2020-01-08_17-25/1, image ID: image_458
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/rpi6_2020-01-08_17-25/2, image ID: image_463
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/rpi6_2020-01-08_17-25/3, image ID: image_468
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/rpi6_2020-01-08_17-25/4, image ID: image_473
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/rpi6_2020-03-12_17-01/2, image ID: image_478
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/rpi6_2020-03-12_17-01/3, image ID: image_483
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/rpi6_2020-03-12_17-01/4, image ID: image_488
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/rpi6_2020-05-20_16-39/1, image ID: image_493
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/rpi6_2020-05-20_16-39/2, image ID: image_499
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/rpi6_2020-05-20_16-39/3, image ID: image_505
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/rpi6_2020-05-20_16-39/4, image ID: image_511
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/rpi6_2020-08-06_14-01/1, image ID: image_517
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/rpi6_2020-08-06_14-01/2, image ID: image_523
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/rpi6_2020-08-06_14-01/4, image ID: image_529
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/rpi6_old/cam1, image ID: image_535
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/rpi6_old/cam2, image ID: image_541
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/rpi6_old/cam3, image ID: image_548
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/rpi6_old/cam4, image ID: image_555
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/rpi8_2020-08-06_14-02/1, image ID: image_561
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/rpi8_2020-08-06_14-02/2, image ID: image_567
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/rpi8_2020-08-06_14-02/3, image ID: image_573
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/rpi8_2020-08-06_14-02/4, image ID: image_579
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/rpi9_2020-08-06_14-02/1, image ID: image_585
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/rpi9_2020-08-06_14-02/2, image ID: image_591
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/rpi9_2020-08-06_14-02/4, image ID: image_597
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/rpi13_old/cam1, image ID: image_603
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/rpi13_old/cam2, image ID: image_611
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/rpi13_old/cam3, image ID: image_619
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/rpi13_old/cam4, image ID: image_627
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/rpi14_2019-12-09_16-13/1, image ID: image_634
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/rpi14_2019-12-09_16-13/2, image ID: image_639
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/rpi14_2019-12-09_16-13/3, image ID: image_644
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/rpi14_2019-12-09_16-13/4, image ID: image_649
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/rpi14_2020-01-08_17-25/1, image ID: image_654
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/rpi14_2020-01-08_17-25/3, image ID: image_659
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/rpi14_2020-01-08_17-25/4, image ID: image_664
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/rpi14_2020-03-12_17-00/1, image ID: image_668
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/rpi14_2020-03-12_17-00/2, image ID: image_673
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/rpi14_2020-03-12_17-00/3, image ID: image_678
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/rpi14_2020-03-12_17-00/4, image ID: image_683
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/rpi14_2020-05-20_17-12/1, image ID: image_688
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/rpi14_2020-05-20_17-12/2, image ID: image_694
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/rpi14_2020-05-20_17-12/3, image ID: image_700
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/rpi14_2020-05-20_17-12/4, image ID: image_706
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/rpi14_old/cam1, image ID: image_712
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/rpi14_old/cam2, image ID: image_721
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/rpi14_old/cam3, image ID: image_729
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/rpi14_old/cam4, image ID: image_737
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/rpi15_2019-12-09_16-14/1, image ID: image_746
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/rpi15_2019-12-09_16-14/2, image ID: image_751
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/rpi15_2019-12-09_16-14/3, image ID: image_756
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/rpi15_2019-12-09_16-14/4, image ID: image_761
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/rpi15_2020-01-08_17-24/1, image ID: image_764
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/rpi15_2020-01-08_17-24/3, image ID: image_769
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/rpi15_2020-01-08_17-24/4, image ID: image_774
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/rpi15_2020-03-12_17-01/1, image ID: image_779
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/rpi15_2020-03-12_17-01/2, image ID: image_784
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/rpi15_2020-03-12_17-01/3, image ID: image_789
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/rpi15_2020-03-12_17-01/4, image ID: image_794
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/rpi15_2020-05-24_10-21/1, image ID: image_799
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/rpi15_2020-05-24_10-21/2, image ID: image_805
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/rpi15_2020-05-24_10-21/3, image ID: image_811
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/rpi15_2020-05-24_10-21/4, image ID: image_817
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/rpi15_old/cam1, image ID: image_823
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/rpi15_old/cam2, image ID: image_830
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/rpi15_old/cam3, image ID: image_838
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/rpi15_old/cam4, image ID: image_847
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/test_1/1, image ID: image_856
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/test_1/2, image ID: image_861
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/test_1/3, image ID: image_866
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/test_1/4, image ID: image_871
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/test_2/1, image ID: image_876
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/test_2/2, image ID: image_881
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/test_2/3, image ID: image_886
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/test_2/4, image ID: image_891
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/test_3/2, image ID: image_896
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/test_3/3, image ID: image_901
# Processing /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/ArabidopsisDataset/Roots/test_3/4, image ID: image_906

# %%
import json
import numpy as np
import os
import random

# Path to the folder_image_map.json file
folder_map_path = '/Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/nnUNet_temp_rebuild/Dataset789_ChronoRoot2/folder_image_map.json'

# Path to save the splits file
splits_output_path = '/Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/nnUNet_temp_rebuild/Dataset789_ChronoRoot2/splits_final.json'

# Make directories if they don't exist
os.makedirs(os.path.dirname(splits_output_path), exist_ok=True)

# Load the folder-to-images mapping
with open(folder_map_path, 'r') as f:
    folder_image_map = json.load(f)

# Set a seed for reproducibility
random.seed(42)
np.random.seed(42)

# Group folders by major category
major_categories = {}
for folder_id in folder_image_map.keys():
    # Extract major category from folder name
    # Format: Manual_Annotation_ArabidopsisDataset_<CATEGORY>_...
    parts = folder_id.split('_')
    if len(parts) >= 4:
        category = parts[3]  # Etiolation, Germination, ManyRoots, or Roots
        if category not in major_categories:
            major_categories[category] = []
        major_categories[category].append(folder_id)

print("Major categories found:")
for cat, folders in major_categories.items():
    print(f"  {cat}: {len(folders)} folders")

# Initialize train, val, test lists
train_folders = []
val_folders = []
test_folders = []

# Process each major category
for category, folders in major_categories.items():
    print(f"\nProcessing category: {category}")
    
    # Separate MultipleVids folders (always go to train)
    multiplevids_folders = [f for f in folders if "MultipleVids" in f]
    other_folders = [f for f in folders if "MultipleVids" not in f]
    
    print(f"  MultipleVids folders: {len(multiplevids_folders)} (→ train)")
    print(f"  Other folders: {len(other_folders)}")
    
    # Add MultipleVids folders to train
    train_folders.extend(multiplevids_folders)
    
    # Shuffle other folders
    random.shuffle(other_folders)
    
    # Calculate split sizes (70-10-20)
    n_other = len(other_folders)
    n_train = int(0.7 * n_other)
    n_val = int(0.1 * n_other)
    # n_test is the remainder
    
    # Split the other folders
    train_other = other_folders[:n_train]
    val_other = other_folders[n_train:n_train + n_val]
    test_other = other_folders[n_train + n_val:]
    
    print(f"  Split: {len(train_other)} train, {len(val_other)} val, {len(test_other)} test")
    
    # Add to respective lists
    train_folders.extend(train_other)
    val_folders.extend(val_other)
    test_folders.extend(test_other)

# Convert folder lists to image lists
train_images = []
val_images = []
test_images = []

for folder in train_folders:
    train_images.extend(folder_image_map[folder])

for folder in val_folders:
    val_images.extend(folder_image_map[folder])

for folder in test_folders:
    test_images.extend(folder_image_map[folder])

# Create the split dictionary (single split with train/val/test)
splits = [{
    'train': train_images,
    'val': val_images,
    'test': test_images
}]

# Print statistics
print(f"\n{'='*60}")
print(f"FINAL SPLIT STATISTICS")
print(f"{'='*60}")
print(f"Total folders: {len(folder_image_map)}")
print(f"  Train folders: {len(train_folders)}")
print(f"  Val folders: {len(val_folders)}")
print(f"  Test folders: {len(test_folders)}")
print(f"\nTotal images: {len(train_images) + len(val_images) + len(test_images)}")
print(f"  Train images: {len(train_images)} ({100*len(train_images)/(len(train_images)+len(val_images)+len(test_images)):.1f}%)")
print(f"  Val images: {len(val_images)} ({100*len(val_images)/(len(train_images)+len(val_images)+len(test_images)):.1f}%)")
print(f"  Test images: {len(test_images)} ({100*len(test_images)/(len(train_images)+len(val_images)+len(test_images)):.1f}%)")

# Save the splits
with open(splits_output_path, 'w') as f:
    json.dump(splits, f, indent=4)

print(f"\nSplits saved to: {splits_output_path}")

# Also save folder assignments for transparency
folder_assignments = {
    'train_folders': train_folders,
    'val_folders': val_folders,
    'test_folders': test_folders
}

folder_assignments_path = splits_output_path.replace('splits_final.json', 'folder_assignments.json')
with open(folder_assignments_path, 'w') as f:
    json.dump(folder_assignments, f, indent=4)

print(f"Folder assignments saved to: {folder_assignments_path}")
# Out:
# Major categories found:
#   Users: 168 folders
#
# Processing category: Users
#   MultipleVids folders: 5 (→ train)
#   Other folders: 163
#   Split: 114 train, 16 val, 33 test
#
# ============================================================
# FINAL SPLIT STATISTICS
# ============================================================
# Total folders: 168
#   Train folders: 119
#   Val folders: 16
#   Test folders: 33
#
# Total images: 911
#   Train images: 683 (75.0%)
#   Val images: 72 (7.9%)
#   Test images: 156 (17.1%)
#
# Splits saved to: /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/nnUNet_temp_rebuild/Dataset789_ChronoRoot2/splits_final.json
# Folder assignments saved to: /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/nnUNet_temp_rebuild/Dataset789_ChronoRoot2/folder_assignments.json

# %%
import json
import shutil
import os

# Paths
splits_path = '/Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/nnUNet_temp_rebuild/Dataset789_ChronoRoot2/splits_final.json'
images_tr_path = "/Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/nnUNet_temp_rebuild/Dataset789_ChronoRoot2/imagesTr"
labels_tr_path = "/Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/nnUNet_temp_rebuild/Dataset789_ChronoRoot2/labelsTr"

images_ts_path = "/Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/nnUNet_temp_rebuild/Dataset789_ChronoRoot2/imagesTs"
labels_ts_path = "/Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/nnUNet_temp_rebuild/Dataset789_ChronoRoot2/labelsTs"

# Create output directories
os.makedirs(images_ts_path, exist_ok=True)
os.makedirs(labels_ts_path, exist_ok=True)

# Load the splits
with open(splits_path, 'r') as f:
    splits = json.load(f)

# Get test images (assuming first split contains train/val/test)
test_images = splits[0]['test']

print(f"Copying {len(test_images)} test images...")

# Copy each test image and its label
for image_id in test_images:
    # Copy image
    src_image = os.path.join(images_tr_path, f'{image_id}_0000.png')
    dst_image = os.path.join(images_ts_path, f'{image_id}_0000.png')
    
    if os.path.exists(src_image):
        shutil.copy(src_image, dst_image)
    else:
        print(f"Warning: Image not found: {src_image}")
    
    # Copy label
    src_label = os.path.join(labels_tr_path, f'{image_id}.png')
    dst_label = os.path.join(labels_ts_path, f'{image_id}.png')
    
    if os.path.exists(src_label):
        shutil.copy(src_label, dst_label)
    else:
        print(f"Warning: Label not found: {src_label}")

print(f"\nDone!")
print(f"Images copied to: {images_ts_path}")
print(f"Labels copied to: {labels_ts_path}")
# Out:
# Copying 156 test images...
#
# Done!
# Images copied to: /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/nnUNet_temp_rebuild/Dataset789_ChronoRoot2/imagesTs
# Labels copied to: /Users/calvinyong/Desktop/UW Madison/Research Materials/Dataset/ChronoRoot2_RawDownload/nnUNet_temp_rebuild/Dataset789_ChronoRoot2/labelsTs
